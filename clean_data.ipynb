# %%
import pandas as pd

# %%
x=pd.read_csv("loan_dirty.csv")

# %%
x
# Out:
#       loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0          2500         2500             2500   36 months     13.56
# 1         30000        30000            30000   60 months     18.94
# 2          5000         5000             5000   36 months     17.97
# 3          4000         4000             4000   36 months     18.94
# 4         30000        30000            30000   60 months     16.14
# ...         ...          ...              ...         ...       ...
# 5994       6000         6000             6000   36 months      7.56
# 5995      16000        16000            16000   60 months     12.98
# 5996      10000        10000            10000   60 months     22.35
# 5997      19200        19200            19200   60 months     15.02
# 5998       2000         2000             2000   36 months      8.19
#
#       installment grade sub_grade               emp_title emp_length  \
# 0           84.92     C        C1                    Chef  10+ years
# ...

# %%
#The number of missing values in each column
x.isnull().sum()
# Out:
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                  484
# sub_grade              484
# emp_title              902
# emp_length             459
# home_ownership         538
# annual_inc             292
# verification_status    432
# issue_d                  0
# loan_status              0
# purpose                  0
# title                    0
# zip_code                 0
# addr_state               0
# dtype: int64

# %%
#only annual income is numerical data.. we fill it up with mean
x_fill=x.fillna(x.mean())

# %%
#Now number of missing values in annual_inc is zero
x_fill.isnull().sum()
# Out:
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                  484
# sub_grade              484
# emp_title              902
# emp_length             459
# home_ownership         538
# annual_inc               0
# verification_status    432
# issue_d                  0
# loan_status              0
# purpose                  0
# title                    0
# zip_code                 0
# addr_state               0
# dtype: int64

# %%
#filling up columns with missing categorical data values
#ffill is forward fill that fills the nan value with previous valid element
x_fill=x_fill.fillna(method="ffill")

# %%
#Now no nan values in dataset
#All null values have been suitably filled
print(x_fill.isnull().sum())
# Out:
# loan_amnt              0
# funded_amnt            0
# funded_amnt_inv        0
# term                   0
# int_rate               0
# installment            0
# grade                  0
# sub_grade              0
# emp_title              0
# emp_length             0
# home_ownership         0
# annual_inc             0
# verification_status    0
# issue_d                0
# loan_status            0
# purpose                0
# title                  0
# zip_code               0
# addr_state             0
# dtype: int64

# %%
#Saving the cleaned dataset to a new csv file called loan_clean.csv
x_fill.to_csv("loan_clean.csv")

# %%
x_fill
# Out:
#       loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0          2500         2500             2500   36 months     13.56
# 1         30000        30000            30000   60 months     18.94
# 2          5000         5000             5000   36 months     17.97
# 3          4000         4000             4000   36 months     18.94
# 4         30000        30000            30000   60 months     16.14
# ...         ...          ...              ...         ...       ...
# 5994       6000         6000             6000   36 months      7.56
# 5995      16000        16000            16000   60 months     12.98
# 5996      10000        10000            10000   60 months     22.35
# 5997      19200        19200            19200   60 months     15.02
# 5998       2000         2000             2000   36 months      8.19
#
#       installment grade sub_grade               emp_title emp_length  \
# 0           84.92     C        C1                    Chef  10+ years
# ...

# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
sns.set(style="whitegrid")

# %%
ac = sns.factorplot(x="purpose",y='annual_inc',size=6,aspect=3,kind='bar',data=x_fill)
# Out:
# C:\Users\Akhil\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Akhil\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ay = sns.scatterplot(x="funded_amnt",y="installment",data=x_fill, hue="term")

# %%
az = sns.boxplot(x="grade",y="loan_amnt",data=x_fill)

# %%
aa = sns.catplot("verification_status", col="sub_grade", col_wrap=4,data=x_fill,kind="count")

# %%
r=0;m=0;o=0;a=0
for index,row in x_fill['home_ownership'].iteritems():
    if(row=='RENT'):
        r=r+1
    elif(row=='MORTGAGE'):
        m=m+1
    elif(row=="OWN"):
        o=o+1
    else:
        a=a+1
        
print(r,a,o,m)
# Out:
# 2388 10 598 3003

# %%
plt.pyplot.pie([r,m,o,a],labels=['Rent','Mortgage','Own','Any'],
               autopct='%1.1f%%',startangle=90,shadow=True,explode=(0,0,0,0.2))
# Out:
# ([<matplotlib.patches.Wedge at 0x258800aab70>,
# ...
#  [Text(-1.0440779509598765, 0.34626757330051244, 'Rent'),
#   Text(0.8832010524356098, -0.6557102263779568, 'Mortgage'),
#   Text(0.3498197111912328, 1.0428931726989503, 'Own'),
#   Text(0.006808100547889198, 1.2999821728650476, 'Any')],
#  [Text(-0.5694970641599326, 0.18887322180027952, '39.8%'),
#   Text(0.4817460286012416, -0.3576601234788855, '50.1%'),
#   Text(0.1908107515588542, 0.5688508214721546, '10.0%'),
#   Text(0.0041896003371625825, 0.7999890294554137, '0.2%')])

# %%
ac = sns.factorplot(x="purpose",y='annual_inc',size=6,aspect=3,kind='bar',data=x_fill)
#inference:Annual income is heighest for people applying for small business among all the people who apply for loans
# Out:
# C:\Users\Akhil\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Akhil\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ay = sns.scatterplot(x="funded_amnt",y="installment",data=x_fill, hue="term")
#inference: Installment amount for 36-month period is always greater than 60-month period for a specific value of the funded amount

# %%
az = sns.boxplot(x="grade",y="loan_amnt",data=x_fill)
#inference1: Bank doesn't lend 'F' grade citizens
#inference2: Loan amount for 'B' grade citizens' loans is the heighest of all

# %%
aa = sns.catplot("verification_status", col="sub_grade", col_wrap=4,data=x_fill,kind="count")
#inference1: Sub grade -F4,F5 : TLoans lent for these category people is Zero
#inference2: In general, No. of people weren't verified is greater than no. of people who were verfied

# %%
r=0;m=0;o=0;a=0
for index,row in x_fill['home_ownership'].iteritems():
    if(row=='RENT'):
        r=r+1
    elif(row=='MORTGAGE'):
        m=m+1
    elif(row=="OWN"):
        o=o+1
    else:
        a=a+1
        
print(r,a,o,m)
# Out:
# 2388 10 598 3003

# %%
plt.pyplot.pie([r,m,o,a],labels=['Rent','Mortgage','Own','Any'],
               autopct='%1.1f%%',startangle=90,shadow=True,explode=(0,0,0,0.2))
#inference: Mortgage loans constitute about 50% of all the loans
# Out:
# ([<matplotlib.patches.Wedge at 0x2588283b630>,
# ...
#  [Text(-1.0440779509598765, 0.34626757330051244, 'Rent'),
#   Text(0.8832010524356098, -0.6557102263779568, 'Mortgage'),
#   Text(0.3498197111912328, 1.0428931726989503, 'Own'),
#   Text(0.006808100547889198, 1.2999821728650476, 'Any')],
#  [Text(-0.5694970641599326, 0.18887322180027952, '39.8%'),
#   Text(0.4817460286012416, -0.3576601234788855, '50.1%'),
#   Text(0.1908107515588542, 0.5688508214721546, '10.0%'),
#   Text(0.0041896003371625825, 0.7999890294554137, '0.2%')])

# %%
x_fill['emp_length']
y=[]
for i in x_fill['emp_length']:
    if i not in y:
        y.append(i)
#Now we start working on correlations

# %%
y
# Out:
# ['10+ years',
#  '6 years',
#  '4 years',
#  '< 1 year',
#  '2 years',
#  '9 years',
#  '5 years',
#  '3 years',
#  '7 years',
#  '1 year',
#  '8 years']

# %%
'''
emp_lengths=[]
for i in x_fill['emp_length']:
    if (i==y[0]):
        emp_lengths.append'''
emp_lengths=x_fill['emp_length']
emp_lengths=emp_lengths.replace('10+ years',10)

emp_lengths=emp_lengths.replace('6 years',6)
emp_lengths=emp_lengths.replace('4 years',4)
emp_lengths=emp_lengths.replace('< 1 year',0)
emp_lengths=emp_lengths.replace('2 years',2)
emp_lengths=emp_lengths.replace('9 years',9)
emp_lengths=emp_lengths.replace('5 years',5)
emp_lengths=emp_lengths.replace('3 years',3)
emp_lengths=emp_lengths.replace('7 years',7)
emp_lengths=emp_lengths.replace('1 year',1)
emp_lengths=emp_lengths.replace('8 years',8)

# %%
import pingouin as pg
pg.corr(x=x_fill['loan_amnt'], y=emp_lengths)
#no strong correlation between employement length and loan amount
# Out:
#             n      r         CI95%     r2  adj_r2     p-val BF10  power
# pearson  5999  0.043  [0.02, 0.07]  0.002   0.002  0.000876  4.1  0.914

# %%
from matplotlib import pyplot
pyplot.scatter(x_fill['loan_amnt'],x_fill['int_rate'])
#No correlation

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from scipy.stats import norm

# %%
corrmat = x_fill.corr() 

f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
#Since correlation can only be found for numerical data, we covert grades to their numerical equivalent
grades=[]
for i in x_fill['grade']:
    #print(ord(i))
    grades.append(ord(i)-65)

# %%
x_fill['loan_amnt'].describe()
# Out:
# count     5999.000000
# mean     16304.434072
# std      10418.508522
# min       1000.000000
# 25%       8000.000000
# 50%      14400.000000
# 75%      23000.000000
# max      40000.000000
# Name: loan_amnt, dtype: float64

# %%
x_fill['installment'].describe()
# Out:
# count    5999.000000
# mean      468.129838
# std       289.259306
# min        30.640000
# 25%       251.400000
# 50%       394.160000
# 75%       628.490000
# max      1424.320000
# Name: installment, dtype: float64

# %%
import numpy as np
import pandas as pd
import pingouin as pg

# %%
pg.corr(x=x_fill['int_rate'], y=grades)
#High Positive Correlation between grade of loan and interest rates
# Out:
#             n      r        CI95%     r2  adj_r2  p-val BF10  power
# pearson  5999  0.901  [0.9, 0.91]  0.812   0.812    0.0  inf    1.0

# %%
pg.corr(x=x_fill['loan_amnt'], y=x_fill['installment'])
#High Correlation
# Out:
#             n      r         CI95%     r2  adj_r2  p-val BF10  power
# pearson  5999  0.939  [0.94, 0.94]  0.882   0.882    0.0  inf    1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
sns.set(style='white', font_scale=1.2)
g = sns.JointGrid(data=x_fill, x='loan_amnt', y='installment', xlim=(1000,40000), ylim=(30, 1425), height=10)
g = g.plot_joint(sns.regplot, color="xkcd:muted blue")
g = g.plot_marginals(sns.distplot, kde=False, bins=12, color="xkcd:bluey grey")
g.ax_joint.text(145, 95, 'r = 0.45, p < .001', fontstyle='italic')
plt.show()

# %%
#Correlation Matrix
x_fill.corr().round(4)
#It is clear that they are not looking at the annual income when giving out the loans
# Out:
#                  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt           1.0000       1.0000           1.0000   -0.0471
# funded_amnt         1.0000       1.0000           1.0000   -0.0471
# funded_amnt_inv     1.0000       1.0000           1.0000   -0.0470
# int_rate           -0.0471      -0.0471          -0.0470    1.0000
# installment         0.9393       0.9393           0.9393   -0.0040
# annual_inc          0.2312       0.2312           0.2312   -0.0722
#
#                  installment  annual_inc
# loan_amnt             0.9393      0.2312
# funded_amnt           0.9393      0.2312
# funded_amnt_inv       0.9393      0.2312
# int_rate             -0.0040     -0.0722
# installment           1.0000      0.2268
# annual_inc            0.2268      1.0000

# %%
import pingouin as pg
pg.corr(x=grades, y=emp_lengths)
#No relationship between grades and employement length
# Out:
#             n      r          CI95%   r2  adj_r2     p-val   BF10  power
# pearson  5999  0.001  [-0.02, 0.03]  0.0    -0.0  0.911931  0.016  0.051

# %%
import pingouin as pg
pg.corr(x=x_fill['int_rate'], y=emp_lengths)
#No correlation between employement length and interest rates
# Out:
#             n      r          CI95%   r2  adj_r2     p-val   BF10  power
# pearson  5999  0.007  [-0.02, 0.03]  0.0    -0.0  0.614308  0.018   0.08
